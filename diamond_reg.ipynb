# %%
import pandas as pd

# %%
# To perform machine learning, we need at least 1 python package and 2 of its modules
from sklearn.linear_model import LinearRegression # linear regression

# Train-test split package
from sklearn.model_selection import train_test_split # split your dataset

# %%
data_frame = pd.read_csv("diamonds_regression.csv")

# %%
data_frame.head(5)
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
columns = ['carat', 'cut', 'color', 'clarity', 'depth', 'table']

# %%
target = 'price'

# %%
X = data_frame[columns]
y = data_frame[target]

# %%
X
# Out:
#        carat        cut color clarity  depth  table
# 0       0.23      Ideal     E     SI2   61.5   55.0
# 1       0.21    Premium     E     SI1   59.8   61.0
# 2       0.23       Good     E     VS1   56.9   65.0
# 3       0.29    Premium     I     VS2   62.4   58.0
# 4       0.31       Good     J     SI2   63.3   58.0
# ...      ...        ...   ...     ...    ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0
# 53936   0.72       Good     D     SI1   63.1   55.0
# 53937   0.70  Very Good     D     SI1   62.8   60.0
# 53938   0.86    Premium     H     SI2   61.0   58.0
# 53939   0.75      Ideal     D     SI2   62.2   55.0
#
# [53940 rows x 6 columns]

# %%
X_dummies = pd.get_dummies(X)

# %%
X_dummies
# Out:
#        carat  depth  table  cut_Fair  cut_Good  cut_Ideal  cut_Premium  \
# 0       0.23   61.5   55.0         0         0          1            0
# 1       0.21   59.8   61.0         0         0          0            1
# 2       0.23   56.9   65.0         0         1          0            0
# 3       0.29   62.4   58.0         0         0          0            1
# 4       0.31   63.3   58.0         0         1          0            0
# ...      ...    ...    ...       ...       ...        ...          ...
# 53935   0.72   60.8   57.0         0         0          1            0
# 53936   0.72   63.1   55.0         0         1          0            0
# 53937   0.70   62.8   60.0         0         0          0            0
# 53938   0.86   61.0   58.0         0         0          0            1
# 53939   0.75   62.2   55.0         0         0          1            0
#
#        cut_Very Good  color_D  color_E  ...  color_I  color_J  clarity_I1  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.9154105155614831

# %%
filename = 'diamonds_regression.sav'

# %%
import joblib
joblib.dump(model, filename)
# Out:
# ['diamonds_regression.sav']

# %%
columns = ['carat', 'cut', 'depth', 'table']

# %%
data_frame[columns]
# Out:
#        carat        cut  depth  table
# 0       0.23      Ideal   61.5   55.0
# 1       0.21    Premium   59.8   61.0
# 2       0.23       Good   56.9   65.0
# 3       0.29    Premium   62.4   58.0
# 4       0.31       Good   63.3   58.0
# ...      ...        ...    ...    ...
# 53935   0.72      Ideal   60.8   57.0
# 53936   0.72       Good   63.1   55.0
# 53937   0.70  Very Good   62.8   60.0
# 53938   0.86    Premium   61.0   58.0
# 53939   0.75      Ideal   62.2   55.0
#
# [53940 rows x 4 columns]

# %%
X = data_frame[columns]

# %%
X
# Out:
#        carat        cut  depth  table
# 0       0.23      Ideal   61.5   55.0
# 1       0.21    Premium   59.8   61.0
# 2       0.23       Good   56.9   65.0
# 3       0.29    Premium   62.4   58.0
# 4       0.31       Good   63.3   58.0
# ...      ...        ...    ...    ...
# 53935   0.72      Ideal   60.8   57.0
# 53936   0.72       Good   63.1   55.0
# 53937   0.70  Very Good   62.8   60.0
# 53938   0.86    Premium   61.0   58.0
# 53939   0.75      Ideal   62.2   55.0
#
# [53940 rows x 4 columns]

# %%
X_dummies = pd.get_dummies(X)

# %%
X_dummies
# Out:
#        carat  depth  table  cut_Fair  cut_Good  cut_Ideal  cut_Premium  \
# 0       0.23   61.5   55.0         0         0          1            0
# 1       0.21   59.8   61.0         0         0          0            1
# 2       0.23   56.9   65.0         0         1          0            0
# 3       0.29   62.4   58.0         0         0          0            1
# 4       0.31   63.3   58.0         0         1          0            0
# ...      ...    ...    ...       ...       ...        ...          ...
# 53935   0.72   60.8   57.0         0         0          1            0
# 53936   0.72   63.1   55.0         0         1          0            0
# 53937   0.70   62.8   60.0         0         0          0            0
# 53938   0.86   61.0   58.0         0         0          0            1
# 53939   0.75   62.2   55.0         0         0          1            0
#
#        cut_Very Good
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.8564655625875285

# %%
filename = 'final_diamonds_regression.sav'
joblib.dump(model, filename)
# Out:
# ['final_diamonds_regression.sav']

# %%
model.score(X_test, y_test)
# Out:
# 0.8564655625875285

# %%
data = pd.read_csv('diamonds_regression.csv')

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
sns.scatterplot(data=data,
                x='carat',
                y='x',
               hue='price')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='x'>

# %%
sns.scatterplot(data=data,
                x='carat',
                y='y',
               hue='price')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='y'>

# %%
sns.scatterplot(data=data,
                x='carat',
                y='x',
               hue='price')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='x'>

# %%
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
sns.scatterplot(data=data,
                x='carat',
                y='cut',
               hue='price')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='cut'>
